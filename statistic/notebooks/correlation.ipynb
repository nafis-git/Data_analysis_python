# %% [markdown]
# # corrolation

# %% [markdown]
# > In this exercise, you'll examine the relationship between a country's life expectancy (life_exp) and happiness score (happiness_score) both visually and quantitatively.
# - Create a scatterplot of social_support vs. life_exp (without a trendline) using seaborn
# - Create a scatterplot of social_support vs. life_exp with a linear trendline using seaborn, setting ci to None

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
urls = 'https://raw.githubusercontent.com/nafis-git/Data_analysis_python/main/statistic/data/happiness.csv'
df =  pd.read_csv(urls)

# %%
df
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# 4     Afghanistan  2012     3.782938            7.517126        0.520637
# ...           ...   ...          ...                 ...             ...
# 1699     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1702     Zimbabwe  2017     3.638300            7.549491        0.754147
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 26 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Country name                                              1704 non-null   object
#  1   Year                                                      1704 non-null   int64
#  2   Life Ladder                                               1704 non-null   float64
#  3   Log GDP per capita                                        1676 non-null   float64
#  4   Social support                                            1691 non-null   float64
#  5   Healthy life expectancy at birth                          1676 non-null   float64
#  6   Freedom to make life choices                              1675 non-null   float64
#  7   Generosity                                                1622 non-null   float64
# ...

# %%
cols = ['Country name', 'Social support','Freedom to make life choices', 'Perceptions of corruption', 
       'Generosity', 'Log GDP per capita', 'Healthy life expectancy at birth']

# %%
cols_p = ['country', 'social_support', 'freedom', 'corruption', 'generosity', 'gdp_per_cap', 'life_exp']

# %%
# want to consider just 2018
df_2018 = df.loc[df.Year == 2018,cols]

# %%
df_2018.columns = cols_p

# %%
df_2018
# Out:
#           country  social_support   freedom  corruption  generosity  \
# 10    Afghanistan        0.507516  0.373536    0.927606   -0.084888
# 21        Albania        0.683592  0.824212    0.899129    0.005385
# 28        Algeria        0.798651  0.583381    0.758704   -0.172413
# 45      Argentina        0.899912  0.845895    0.855255   -0.206937
# 58        Armenia        0.814449  0.807644    0.676826   -0.149109
# ...           ...             ...       ...         ...         ...
# 1654    Venezuela        0.886882  0.610855    0.827560   -0.176156
# 1667      Vietnam        0.831945  0.909260    0.808423   -0.039124
# 1678        Yemen        0.789422  0.552726    0.792587         NaN
# 1690       Zambia        0.717720  0.790626    0.810731    0.036644
# 1703     Zimbabwe        0.775388  0.762675    0.844209   -0.038384
#
#       gdp_per_cap   life_exp
# 10       7.494588  52.599998
# 21       9.412399  68.699997
# 28       9.557952  65.900002
# 45       9.809972  68.800003
# ...

# %%
#Create a scatterplot of corruption vs. life_exp (without a trendline) using seaborn.
sns.scatterplot(x = 'life_exp', y = 'social_support', data = df_2018)
# Out:
# <AxesSubplot:xlabel='life_exp', ylabel='social_support'>

# %%
# Create a scatterplot of social_support vs. life_exp with a linear trendline using seaborn, setting ci to None
sns.lmplot(x = 'life_exp', y = 'social_support', data = df_2018, ci = None)

# %%
# Calculate the correlation between life_exp and social_support
cor = df_2018['life_exp'].corr(df_2018['social_support'])
cor
# Out:
# 0.7515137295429335

# %% [markdown]
# ### Non-linear relationship
# - if there is nonlinear relationship between varaible correlation does not reflect the relationship
# > What we see in a nonlinear relationship
#  <img src = "rel_non_lin.png">
#  > What the correlation coefficent see
# <img src = "corr_non_lin.png">

# %%
sns.scatterplot(x ='corruption', y = 'life_exp', data = df_2018 )
# Out:
# <AxesSubplot:xlabel='corruption', ylabel='life_exp'>

# %%
cor = df_2018['corruption'].corr(df_2018['life_exp'])
cor
# Out:
# -0.33326870166302314

# %%
# Add a new column to world_happiness called log_gdp_per_cap that contains the log of gdp_per_cap.
# Create a seaborn scatterplot of log of corruption  and happiness_score and calculate the correlation between them.

# %% [markdown]
# ### Other transformations
# - Log transformation ( log(x) )
# - Square root transformation ( sqrt(x) )
# - Reciprocal transformation ( 1 / x )
# - Combinations of these, e.g.:
# - log(x) and log(y)
# - sqrt(x) and 1 / y

# %%
df_2018['log_life_exp'] = np.log(df_2018['life_exp'])
df_2018['log_corruption'] = np.log(df_2018['corruption'])

# %%
df_2018.head()
# Out:
#         country  social_support   freedom  corruption  generosity  \
# 10  Afghanistan        0.507516  0.373536    0.927606   -0.084888
# 21      Albania        0.683592  0.824212    0.899129    0.005385
# 28      Algeria        0.798651  0.583381    0.758704   -0.172413
# 45    Argentina        0.899912  0.845895    0.855255   -0.206937
# 58      Armenia        0.814449  0.807644    0.676826   -0.149109
#
#     gdp_per_cap   life_exp  log_corruption  log_life_exp
# 10     7.494588  52.599998       -0.075149      3.962716
# 21     9.412399  68.699997       -0.106328      4.229749
# 28     9.557952  65.900002       -0.276143      4.188138
# 45     9.809972  68.800003       -0.156355      4.231204
# 58     9.119424  66.900002       -0.390341      4.203199

# %%
cor = df_2018['log_life_exp'].corr(df_2018['log_corruption'])
cor
# Out:
# -0.32891576277383217

# %%
sns.scatterplot(x ='log_life_exp', y = 'log_corruption', data = df_2018 )
# Out:
# <AxesSubplot:xlabel='log_life_exp', ylabel='log_corruption'>

# %%
df_2018['reci_life_exp'] = np.reciprocal(df_2018['life_exp'])
df_2018['reci_corruption'] = np.reciprocal(df_2018['corruption'])

# %%
df_2018.head()
# Out:
#         country  social_support   freedom  corruption  generosity  \
# 10  Afghanistan        0.507516  0.373536    0.927606   -0.084888
# 21      Albania        0.683592  0.824212    0.899129    0.005385
# 28      Algeria        0.798651  0.583381    0.758704   -0.172413
# 45    Argentina        0.899912  0.845895    0.855255   -0.206937
# 58      Armenia        0.814449  0.807644    0.676826   -0.149109
#
#     gdp_per_cap   life_exp  log_corruption  log_life_exp  reci_life_exp  \
# 10     7.494588  52.599998       -0.075149      3.962716       0.019011
# 21     9.412399  68.699997       -0.106328      4.229749       0.014556
# 28     9.557952  65.900002       -0.276143      4.188138       0.015175
# 45     9.809972  68.800003       -0.156355      4.231204       0.014535
# 58     9.119424  66.900002       -0.390341      4.203199       0.014948
#
#     reci_corruption
# 10         1.078044
# 21         1.112187
# 28         1.318037
# 45         1.169242
# 58         1.477484

# %%
# Reciprocal transformation ( 1 / x )
cor = df_2018['life_exp'].corr(df_2018['reci_corruption'])
cor
# Out:
# 0.3162553141798343

# %%
# sqrt(x) and 1 / y
df_2018['sqrt_life_exp'] = np.sqrt(df_2018['life_exp'])
df_2018['inverse_corruption'] = df_2018['corruption'].transform(lambda x: 1/x)

# %%
df_2018.head()
# Out:
#         country  social_support   freedom  corruption  generosity  \
# 10  Afghanistan        0.507516  0.373536    0.927606   -0.084888
# 21      Albania        0.683592  0.824212    0.899129    0.005385
# 28      Algeria        0.798651  0.583381    0.758704   -0.172413
# 45    Argentina        0.899912  0.845895    0.855255   -0.206937
# 58      Armenia        0.814449  0.807644    0.676826   -0.149109
#
#     gdp_per_cap   life_exp  log_corruption  log_life_exp  reci_life_exp  \
# 10     7.494588  52.599998       -0.075149      3.962716       0.019011
# 21     9.412399  68.699997       -0.106328      4.229749       0.014556
# 28     9.557952  65.900002       -0.276143      4.188138       0.015175
# 45     9.809972  68.800003       -0.156355      4.231204       0.014535
# 58     9.119424  66.900002       -0.390341      4.203199       0.014948
#
#     reci_corruption  sqrt_life_exp  inverse_corruption
# 10         1.078044       7.252586            1.078044
# ...

# %%
cor = df_2018['sqrt_life_exp'].corr(df_2018['corruption'])
cor
# Out:
# -0.3238397083287658

# %% [markdown]
# ### Confounders
# A study is investigating the relationship between neighborhood residence and lung capacity. Researchers measure the lung capacity of thirty people from neighborhood A, which is located near a highway, and thirty people from neighborhood B, which is not near a highway. Both groups have similar smoking habits and a similar gender breakdown.
#
# Which of the following could be a confounder in this study?
# - Lung capacity
# - Neighborhood
# - Air pollution
# - Smoking status
# - Gender

# %% [markdown]
# Experiment aims to answer: What is the e(ect of the treatment on the response?
# Treatment: explanatory/independent variable
# Response: response/dependent variable
# E.g.: What is the e(ect of an advertisement on the number of products purchased?
# Treatment: advertisement
# Response: number of products purchased

# %% [markdown]
# Controlled experiments
# Participants are assigned by researchers to either treatment group or control group
# Treatment group sees advertisement
# Control group does not
# Groups should be comparable so that causation can be inferred
# If groups are not comparable, this could lead to confounding (bias)
# Treatment group average age: 25
# Control group average age: 50
# Age is a potential confounder

# %% [markdown]
# The gold standard of experiments will use...
# Randomized controlled trial
# Participants are assigned to treatment/control randomly, not based on any other
# characteristics
# Choosing randomly helps ensure that groups are comparable
# Placebo
# Resembles treatment, but has no e(ect
# Participants will not know which group they're in
# In clinical trials, a sugar pill ensures that the e(ect of the drug is actually due to the drug
# itself and not the idea of receiving the drug
# Double-blind trial
# Person administering the treatment/running the study doesn't know whether thetreatment is real or a placebo
# Prevents bias in the response and/or analysis of results
# Fewer opportunities for bias = more reliable conclusion about causation

# %% [markdown]
# Observational studies
# Participants are not assigned randomly to groups
# Participants assign themselves, usually based on pre-existing characteristics
# Many research questions are not conducive to a controlled experiment
# You can't force someone to smoke or have a disease
# You can't make someone have certain past behavior
# Establish association, not causation
# E(ects can be confounded by factors that got certain people into the control or
# treatment group
# There are ways to control for confounders to get more reliable conclusions about
# association

# %% [markdown]
# Longitudinal study
# Participants are followed over a period of
# time to examine e(ect of treatment on
# response
# E(ect of age on height is not confounded
# by generation
# More expensive, results take longer

# %% [markdown]
# Cross-sectional study
# Data on participants is collected from a
# single snapshot in time
# E(ect of age on height is confounded by
# generation
# Cheaper, faster, more convenient
